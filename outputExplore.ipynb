# %%
import pandas as pd

# %%
df = pd.read_csv(r"tui_test.csv")

# %%
df.drop_duplicates(subset='holiday_name', ignore_index=True)
# Out:
#      Unnamed: 0                                       holiday_name  \
# 0             0  Universal's Endless Summer Resort - Dockside I...
# 1             1                            TUI MAGIC LIFE Calabria
# 2             2                                       Janna E Sole
# 3             3                                     Hotel La Perla
# 4             4                                   Hotel Conca Park
# ..          ...                                                ...
# 558       15698                           Grand Hotel Piazza Borsa
# 559       16265                                Grand Hotel Minerva
# 560       16266                                Armani Hotel Milano
# 561       16267   Days Inn By Wyndham Washington DC/Connecticut Av
# 562       16268                                          Alexandra
#
#                                               location
# 0    in Universal Orlando Resort, Orlando, Florida,...
# ...
